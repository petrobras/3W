# %% [markdown]
# # Correlation Heatmap Demonstration
#
# This notebook demonstrates how to use the `DataVisualization.correlation_heatmap` function in various scenarios.
#
# The function accepts:
# - A DataFrame of time series (`df_of_series`)
# - Additional keyword arguments (`**kwargs`) for customization (e.g., `title`, `figsize`, `annot`, `cmap`, `ax`, etc.)

# %% [markdown]
# ## Using mock data as example

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from ThreeWToolkit.data_visualization import DataVisualization

# %% [markdown]
# ### Basic Usage

# %%
df = pd.DataFrame(np.random.rand(100, 5), columns=["A", "B", "C", "D", "E"])
fig, _ = DataVisualization.correlation_heatmap(df)
fig.show()
# Out:
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/correlation_heatmap.png'
# /tmp/ipykernel_11601/3233984793.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Custom Title and Annotations

# %%
fig, _ = DataVisualization.correlation_heatmap(
    df, title="Annotated Heatmap", annot=True, cmap="viridis", fmt=".2f"
)
fig.show()
# Out:
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/annotated_heatmap.png'
# /tmp/ipykernel_11601/2754938477.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Custom Figure Size and Color Map

# %%
fig, _ = DataVisualization.correlation_heatmap(
    df,
    title="Larger Heatmap with 'coolwarm'",
    figsize=(14, 10),
    cmap="coolwarm",
    annot=True,
)
fig.show()
# Out:
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/larger_heatmap_with_coolwarm.png'
# /tmp/ipykernel_11601/1294291744.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Multiple Heatmaps in Subplots

# %%
df2 = pd.DataFrame(np.random.rand(100, 4), columns=["W", "X", "Y", "Z"])

fig, axs = plt.subplots(1, 2, figsize=(16, 6))
DataVisualization.correlation_heatmap(df, ax=axs[0], title="Dataset 1", annot=True)
DataVisualization.correlation_heatmap(
    df2, ax=axs[1], title="Dataset 2", cmap="crest", annot=True
)
plt.tight_layout()
plt.show()
# Out:
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/dataset_1.png'
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/dataset_2.png'

# %% [markdown]
# ## Using 3W data as example

# %%
import matplotlib.pyplot as plt
import numpy as np
from ThreeWToolkit.data_visualization import DataVisualization

# %% [markdown]
# Loading the 3W dataset

# %%
from ThreeWToolkit.core.base_dataset import ParquetDatasetConfig
from ThreeWToolkit.dataset import ParquetDataset
from pathlib import Path

# define path
dataset_path = Path("../../dataset")

# create and load
ds_config = ParquetDatasetConfig(path=dataset_path, clean_data=False)
ds = ParquetDataset(ds_config)
len(ds)
# Out:
# [ParquetDataset] Dataset found at ../../dataset
# [ParquetDataset] Validating dataset integrity...
# [ParquetDataset] Dataset integrity check passed!
# 2228

# %%
sig = ds[123]["signal"].copy()

# %% [markdown]
# ### Basic Usage

# %%
features = ["P-ANULAR", "P-JUS-CKGL", "P-MON-CKP", "P-TPT", "T-JUS-CKP", "T-TPT"]
subset = sig[features]

fig, _ = DataVisualization.correlation_heatmap(
    df_of_series=subset, title="Correlation Heatmap of Selected Features"
)
fig.show()
# Out:
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/correlation_heatmap_of_selected_features.png'
# /tmp/ipykernel_11601/2170412813.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Custom Title and Annotations

# %%
features = ["P-ANULAR", "P-JUS-CKGL", "P-MON-CKP", "P-TPT", "T-JUS-CKP", "T-TPT"]
subset = sig[features]

fig, _ = DataVisualization.correlation_heatmap(
    subset, title="Annotated Heatmap", annot=True, cmap="viridis", fmt=".2f"
)
fig.show()
# Out:
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/annotated_heatmap.png'
# /tmp/ipykernel_11601/4058696118.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Custom Figure Size and Color Map

# %%
features = ["P-ANULAR", "P-JUS-CKGL", "P-MON-CKP", "P-TPT", "T-JUS-CKP", "T-TPT"]
subset = sig[features]

fig, _ = DataVisualization.correlation_heatmap(
    subset,
    title="Larger Heatmap with 'coolwarm'",
    figsize=(14, 10),
    cmap="coolwarm",
    annot=True,
)
fig.show()
# Out:
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/larger_heatmap_with_coolwarm.png'
# /tmp/ipykernel_11601/2212497628.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Multiple Heatmaps in Subplots

# %%
features_1 = ["P-ANULAR", "P-JUS-CKGL", "P-MON-CKP", "P-TPT", "T-JUS-CKP", "T-TPT"]
subset_1 = sig[features_1]

features_2 = ["T-TPT", "P-JUS-CKGL", "P-TPT", "P-MON-CKP", "T-JUS-CKP", "P-ANULAR"]
subset_2 = sig[features_2]

fig, axs = plt.subplots(1, 2, figsize=(16, 6))
DataVisualization.correlation_heatmap(
    subset_1, ax=axs[0], title="Dataset 1", annot=True
)
DataVisualization.correlation_heatmap(
    subset_2, ax=axs[1], title="Dataset 2", cmap="crest", annot=True
)
plt.tight_layout()
plt.show()
# Out:
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/dataset_1.png'
# DataVisualization: Chart saved to '/home/rafael/pos-doc/repos/3W/toolkit/output/3w_plots/dataset_2.png'
